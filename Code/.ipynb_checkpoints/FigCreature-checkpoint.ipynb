# %% [markdown]
# ### Created By: Mohammad Sherafati(Heramn), m.sherafati7@gmail.com, Date: 29.5.2019

# %% [markdown]
# #### Import Package

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read Data

# %%
Mean_Func16 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/EFinal'+str(16)+'.txt')
Thres16 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/T'+str(16)+'.txt')

# %%
print(len(Mean_Func16))
print(len(Mean_Func16))
# Out:
# 125
# 125

# %%
Mean_Func32 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/EFinal'+str(32)+'.txt')
Thres32 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/T'+str(32)+'.txt')

# %%
print(len(Mean_Func32))
print(len(Mean_Func32))
# Out:
# 161
# 161

# %%
Mean_Func64 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/EFinal'+str(64)+'.txt')
Thres64 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/T'+str(64)+'.txt')

# %%
print(len(Mean_Func64[:125]))
print(len(Mean_Func64))
# Out:
# 125
# 381

# %%
Mean_Func128 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/EFinal'+str(128)+'.txt')
Thres128 = np.loadtxt('/home/mohammad/Documents/Thesis/Results/Transition Point/T'+str(128)+'.txt')

# %%
print(len(Mean_Func128))
print(len(Mean_Func128))
# Out:
# 351
# 351

# %%
Mean_Func1 = Mean_Func16[10:60]
Mean_Func2 = Mean_Func32[10:]
Mean_Func3 = Mean_Func64[:200]
Mean_Func4 = Mean_Func128

# %%
Thres1 = Thres16[10:60]
Thres2 = Thres32[10:]
Thres3 = Thres64[:200]
Thres4 = Thres128

# %%
plt.plot(Thres1,Mean_Func1,label="16")
plt.plot(Thres2,Mean_Func2,color='orange',label="32")
plt.plot(Thres3,Mean_Func3,marker='',color='green',label="64")
plt.plot(Thres4,Mean_Func4,marker='',color='red',label="128")
plt.xlabel('Life Time (Time/(N,2))')
plt.ylabel('Energy ensenble')
plt.title('(128-64-32-16) ')
plt.legend()
plt.grid(True, lw = 2, ls = '--', c = '.5')
plt.savefig('(128,64-32-16)-LifTime.png',figsize = (12,7),dpi=300)

# %%
#plt.plot(Thres1,Mean_Func1)
plt.plot(Thres2,Mean_Func2,color='orange',label="32")
plt.plot(Thres3,Mean_Func3,marker='',color='green',label="64")
plt.plot(Thres4,Mean_Func4,marker='',color='red',label="128")
plt.xlabel('Life Time (Time/(N,2))')
plt.ylabel('Energy ensenble')
plt.title('(128-64-32) ')
plt.legend()
plt.grid(True, lw = 2, ls = '--', c = '.5')
plt.savefig('(128,64-32)-LifTime.png',figsize = (16,9),dpi=300)
